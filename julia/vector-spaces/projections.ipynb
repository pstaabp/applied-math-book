# %%
u₁ = [3; 0; -1]
u₂ = [1; -5; 3]
# Out:
# 3-element Vector{Int64}:
#   1
#  -5
#   3

# %%
e₁ = [1; 0; 0]
e₂ = [0; 1; 0]
e₃ = [0; 0; 1]
# Out:
# 3-element Vector{Int64}:
#  0
#  0
#  1

# %%
(e₁'*u₁)//(u₁'*u₁)* u₁ .+ e₁'*u₂//(u₂'*u₂) * u₂
# Out:
# 3-element Vector{Rational{Int64}}:
#  13//14
#  -1//7
#  -3//14

# %%
e₂'*u₁//(u₁'*u₁)* u₁ .+ e₂'*u₂//(u₂'*u₂)*u₂
# Out:
# 3-element Vector{Rational{Int64}}:
#  -1//7
#   5//7
#  -3//7

# %%
e₃'*u₁//(u₁'*u₁)* u₁ .+ e₃'*u₂//(u₂'*u₂)*u₂
# Out:
# 3-element Vector{Rational{Int64}}:
#  -3//14
#  -3//7
#   5//14

# %%
P = [(e₁'*u₁)//(u₁'*u₁)* u₁ .+ e₁'*u₂//(u₂'*u₂) * u₂  e₂'*u₁//(u₁'*u₁)* u₁ .+ e₂'*u₂//(u₂'*u₂)*u₂ e₃'*u₁//(u₁'*u₁)* u₁ .+ e₃'*u₂//(u₂'*u₂)*u₂]
# Out:
# 3×3 Matrix{Rational{Int64}}:
#  13//14  -1//7  -3//14
#  -1//7    5//7  -3//7
#  -3//14  -3//7   5//14

# %%
P*[6;-2;3]
# Out:
# 3-element Vector{Rational{Int64}}:
#   73//14
#  -25//7
#    9//14

# %%
15//10*u₁ + 25//35*u₂
# Out:
# 3-element Vector{Rational{Int64}}:
#   73//14
#  -25//7
#    9//14

# %%
P*e₃
# Out:
# 3-element Vector{Rational{Int64}}:
#  -3//14
#  -3//7
#   5//14

# %%
P^2
# Out:
# 3×3 Matrix{Rational{Int64}}:
#   449//490    -1//7      -3//14
#     8//49    169//245  -114//245
#  -177//490  -103//245   181//490

# %%
A= [u₁ u₂]//1
# Out:
# 3×2 Matrix{Rational{Int64}}:
#   3   1
#   0  -5
#  -1   3

# %%
A*inv(A'*A)*A'
# Out:
# 3×3 Matrix{Rational{Int64}}:
#  13//14  -1//7  -3//14
#  -1//7    5//7  -3//7
#  -3//14  -3//7   5//14

# %%
P
# Out:
# 3×3 Matrix{Rational{Int64}}:
#   13//14  -1//7  -3//14
#    1//35   5//7  -3//7
#  -19//70  -3//7   5//14

# %%
P^2
# Out:
# 3×3 Matrix{Rational{Int64}}:
#  13//14  -1//7  -3//14
#  -1//7    5//7  -3//7
#  -3//14  -3//7   5//14

# %%
A = [1 2; 0 1; -2 1]//1
# Out:
# 3×2 Matrix{Rational{Int64}}:
#   1  2
#   0  1
#  -2  1

# %%
A*inv(A'*A)*A'
# Out:
# 3×3 Matrix{Rational{Int64}}:
#  13//15  1//3  -1//15
#   1//3   1//6   1//6
#  -1//15  1//6  29//30
