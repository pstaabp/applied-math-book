# %%
using LinearAlgebra

# %%
A = [1 0 2; 2 0 4; -1 0 -2]
eigvals(A)
# Out:
# 3-element Vector{Float64}:
#  -1.0
#   0.0
#   0.0

# %%
eigvecs(A)
# Out:
# 3×3 Matrix{Float64}:
#  -0.408248  0.0   0.894427
#  -0.816497  1.0   0.0
#   0.408248  0.0  -0.447214
