# %%
using LinearAlgebra, Latexify

# %%
A = zeros(Int, 3, 3)
while true
  A = rand(-5:5, 3, 3)
  abs(det(A)) == 4 && break
end
A
# Out:
# 3×3 Matrix{Int64}:
#  -3  -2   1
#  -4  -2   2
#   3  -3  -4

# %%
norm(A[:,1])
# Out:
# 5.830951894845301

# %%
A[:,1]/norm(A[:,1])
# Out:
# 3-element Vector{Float64}:
#  -0.5144957554275265
#  -0.6859943405700353
#   0.5144957554275265

# %%
S = [0 -1 2
1 0 1
-2 -1 0]
# Out:
# 3×3 Matrix{Int64}:
#   0  -1  2
#   1   0  1
#  -2  -1  0

# %%
Q = rationalize.((I-S)*inv(I+S), tol = 10e-3)
# Out:
# 3×3 Matrix{Rational{Int64}}:
#  -3//7  -2//7  -6//7
#  -6//7   3//7   2//7
#   2//7   6//7  -3//7

# %%
R = 7*[3 -2 5
0 1 4
0 0 -5]
# Out:
# 3×3 Matrix{Int64}:
#  21  -14   35
#   0    7   28
#   0    0  -35

# %%
A = Q*R
# Out:
# 3×3 Matrix{Rational{Int64}}:
#   -9   4    7
#  -18  15  -28
#    6   2   49

# %%
latexify(A)
# Out:
# L"\begin{equation}
# \left[
# \begin{array}{ccc}
# -9 & 4 & 7 \\
# -18 & 15 & -28 \\
# 6 & 2 & 49 \\
# \end{array}
# \right]
# \end{equation}
# "

# %%
norm(A[:,1])
# Out:
# 21.0

# %%
q1 = A[:,1]// 21
# Out:
# 3-element Vector{Rational{Int64}}:
#  -3//7
#  -6//7
#   2//7

# %%
q1'*A[:,2] *q1
# Out:
# 3-element Vector{Rational{Int64}}:
#   6
#  12
#  -4

# %%
u2 = A[:,2] - q1'*A[:,2] * q1
# Out:
# 3-element Vector{Rational{Int64}}:
#  -2
#   3
#   6

# %%
norm(u2)
# Out:
# 7.0

# %%
q2 = u2 // 7
# Out:
# 3-element Vector{Rational{Int64}}:
#  -2//7
#   3//7
#   6//7

# %%
q2'*A[:,3]
# Out:
# 28//1

# %%
q1'*A[:,3]
# Out:
# 35//1

# %%
u3 = A[:,3] - 28*q2 - 35*q1
# Out:
# 3-element Vector{Rational{Int64}}:
#   30
#  -10
#   15

# %%
norm(u3)
# Out:
# 35.0

# %%
q3 = u3//35
# Out:
# 3-element Vector{Rational{Int64}}:
#   6//7
#  -2//7
#   3//7

# %%
q1
# Out:
# 3-element Vector{Rational{Int64}}:
#  -3//7
#  -6//7
#   2//7

# %%
Q = [q1 q2 q3]
# Out:
# 3×3 Matrix{Rational{Int64}}:
#  -3//7  -2//7   6//7
#  -6//7   3//7  -2//7
#   2//7   6//7   3//7

# %%
Q'*A
# Out:
# 3×3 Matrix{Rational{Int64}}:
#  21  -14  35
#   0    7  28
#   0    0  35

# %%
latexify(Q'*A)
# Out:
# L"\begin{equation}
# \left[
# \begin{array}{ccc}
# 21 & -14 & 35 \\
# 0 & 7 & 28 \\
# 0 & 0 & 35 \\
# \end{array}
# \right]
# \end{equation}
# "

# %%
A = [
  3 -2 1
  6 0 4
  -6 -8 -7
]
# Out:
# 3×3 Matrix{Int64}:
#   3  -2   1
#   6   0   4
#  -6  -8  -7

# %%
norm(A[:,1])
# Out:
# 9.0

# %%
q1 = A[:,1]//9
# Out:
# 3-element Vector{Rational{Int64}}:
#   1//3
#   2//3
#  -2//3

# %%
a2 = A[:,2] - A[:,2]'*q1*q1
# Out:
# 3-element Vector{Rational{Int64}}:
#  -32//9
#  -28//9
#  -44//9

# %%
9*norm(a2)^2/16
# Out:
# 26.0

# %%
q2 = a2 //(11//3)
# Out:
# 3-element Vector{Rational{Int64}}:
#  -32//33
#  -28//33
#   -4//3

# %%
a21 = a2*9//4
# Out:
# 3-element Vector{Rational{Int64}}:
#   -8
#   -7
#  -11

# %%
a21[1]^2+a21[2]^2+a21[3]^2
# Out:
# 234//1

# %%
q2 = a21/sqrt(234)
# Out:
# 3-element Vector{Float64}:
#  -0.5229763603684907
#  -0.4576043153224294
#  -0.7190924955066748

# %%
a3 = A[:,3] - q2'*A[:,3]*q2 - q1'*A[:,3]*q1
# Out:
# 3-element Vector{Float64}:
#  -0.15384615384615374
#   0.11538461538461586
#   0.038461538461538325

# %%
q3 = a3/norm(a3)
# Out:
# 3-element Vector{Float64}:
#  -0.784464540552735
#   0.5883484054145541
#   0.19611613513818318

# %%
Q = [q1 q2 q3]
# Out:
# 3×3 Matrix{Float64}:
#   0.333333  -0.522976  -0.784465
#   0.666667  -0.457604   0.588348
#  -0.666667  -0.719092   0.196116

# %%
-Q'*A
# Out:
# 3×3 Matrix{Float64}:
#  -9.0          -4.66667      -7.66667
#   2.22045e-16  -6.79869      -2.68025
#  -2.07057e-14  -4.44089e-15  -0.196116

# %%
QR = qr(A)
# Out:
# LinearAlgebra.QRCompactWY{Float64, Matrix{Float64}, Matrix{Float64}}
# Q factor: 3×3 LinearAlgebra.QRCompactWYQ{Float64, Matrix{Float64}, Matrix{Float64}}
# R factor:
# 3×3 Matrix{Float64}:
#  -9.0  -4.66667  -7.66667
#   0.0   6.79869   2.68025
#   0.0   0.0      -0.196116

# %%
Matrix(QR.Q)
# Out:
# 3×3 Matrix{Float64}:
#  -0.333333  -0.522976   0.784465
#  -0.666667  -0.457604  -0.588348
#   0.666667  -0.719092  -0.196116

# %%
QR.R
# Out:
# 3×3 Matrix{Float64}:
#  -9.0  -4.66667  -7.66667
#   0.0   6.79869   2.68025
#   0.0   0.0      -0.196116

# %%
QR.R \ (QR.Q'*[14; 22; -9])
# Out:
# 3-element Vector{Float64}:
#   2.999999999999997
#  -2.000000000000001
#   1.0000000000000033

# %% [markdown]
# ### Using QR to find eigenvalues

# %%
A = [1 0 0; 3 -2 6; 2 1 3]
# Out:
# 3×3 Matrix{Int64}:
#  1   0  0
#  3  -2  6
#  2   1  3

# %%
A₀ = A
QR₀ = qr(A₀)
# Out:
# LinearAlgebra.QRCompactWY{Float64, Matrix{Float64}, Matrix{Float64}}
# Q factor: 3×3 LinearAlgebra.QRCompactWYQ{Float64, Matrix{Float64}, Matrix{Float64}}
# R factor:
# 3×3 Matrix{Float64}:
#  -3.74166  1.06904  -6.41427
#   0.0      1.96396  -1.09109
#   0.0      0.0       1.63299

# %%
Matrix(QR₀.R)
# Out:
# 3×3 Matrix{Float64}:
#  -3.74166  1.06904  -6.41427
#   0.0      1.96396  -1.09109
#   0.0      0.0       1.63299

# %%
A₁ = QR₀.R * QR₀.Q
# Out:
# 3×3 Matrix{Float64}:
#   3.57143   -6.29869   1.96396
#  -0.99146   -2.01587  -0.0296957
#  -0.872872   1.30661   0.444444

# %%
QR₁ = qr(A₁)
# Out:
# LinearAlgebra.QRCompactWY{Float64, Matrix{Float64}, Matrix{Float64}}
# Q factor: 3×3 LinearAlgebra.QRCompactWYQ{Float64, Matrix{Float64}, Matrix{Float64}}
# R factor:
# 3×3 Matrix{Float64}:
#  -3.80789  5.6822   -1.74786
#   0.0      3.62727  -0.495724
#   0.0      0.0       0.868795

# %%
A₂ = QR₁.R * QR₁.Q
# Out:
# 3×3 Matrix{Float64}:
#  4.65025   -4.45991      -2.88562
#  0.830799  -3.49591      -0.700881
#  0.199152   0.000981054   0.845661

# %%
QR₂ = qr(A₂)
# Out:
# LinearAlgebra.QRCompactWY{Float64, Matrix{Float64}, Matrix{Float64}}
# Q factor: 3×3 LinearAlgebra.QRCompactWYQ{Float64, Matrix{Float64}, Matrix{Float64}}
# R factor:
# 3×3 Matrix{Float64}:
#  -4.72807  5.00074  2.92566
#   0.0      2.66547  0.258938
#   0.0      0.0      0.952189

# %%
A₃ = QR₂.R * QR₂.Q
# Out:
# 3×3 Matrix{Float64}:
#   3.6483     -5.49122    3.52957
#  -0.479273   -2.59664    0.446711
#  -0.0401072   0.0755963  0.948335

# %%
QR₃ = qr(A₃)
# Out:
# LinearAlgebra.QRCompactWY{Float64, Matrix{Float64}, Matrix{Float64}}
# Q factor: 3×3 LinearAlgebra.QRCompactWYQ{Float64, Matrix{Float64}, Matrix{Float64}}
# R factor:
# 3×3 Matrix{Float64}:
#  -3.67987  5.10675  -3.43078
#   0.0      3.28981  -0.89664
#   0.0      0.0       0.991239

# %%
A₄ = QR₃.R * QR₃.Q
# Out:
# 3×3 Matrix{Float64}:
#  4.27602    -4.60494     -3.44975
#  0.418699   -3.26719     -0.881472
#  0.0108036   0.00600724   0.991162

# %%
Aₖ = A
for i=1:25
  QRₖ = qr(Aₖ)
  Aₖ = QRₖ.R * QRₖ.Q
end
Aₖ
# Out:
# 3×3 Matrix{Float64}:
#   3.99934      -5.00092      3.53563
#  -0.000921692  -2.99934      0.706641
#  -2.34445e-15   1.27349e-12  1.0

# %%
A = zeros(Int,3,3)
while true
  A = rand(-5:5,3,3)
  abs(norm(A[:,1])-3) < 1e-3  && break
end
A
# Out:
# 3×3 Matrix{Int64}:
#  -1   1   3
#   2   2  -2
#   2  -1   5

# %%
qr(A)
# Out:
# LinearAlgebra.QRCompactWY{Float64, Matrix{Float64}, Matrix{Float64}}
# Q factor: 3×3 LinearAlgebra.QRCompactWYQ{Float64, Matrix{Float64}, Matrix{Float64}}
# R factor:
# 3×3 Matrix{Float64}:
#  3.0   0.333333  1.0
#  0.0  -2.4267    2.60985
#  0.0   0.0       5.49442

# %%
A* [4;-2;0]
# Out:
# 3-element Vector{Int64}:
#  -6
#   4
#  10

# %%
A = rand(-4:4,4,4)
# Out:
# 4×4 Matrix{Int64}:
#   4   3  -1  0
#  -1  -3   1  4
#   2   0   2  4
#   2  -1  -4  2
